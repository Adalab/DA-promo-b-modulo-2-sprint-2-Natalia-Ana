# %% [markdown]
# EJERCICIO
#
#  El objetivo es que saquéis la información del clima de la API para los paises que
#
#  - Deberéis meter toda la información climática en un único dataframe.
#
#  - Deberéis hacer la llamada a la API de una sola vez. Es decir, tendréis que iterar por la lista de países y sacar la información del clima para cada uno de ellos.
#
#  - Al meter toda la información en un único dataframe tendremos que crear una columna que corresponda con el nombre del país
#
#  - Guardar el dataframe obtenido para usarlo en la siguiente sesión de pair programming.

# %%
import pandas as pd
import requests
import numpy as np

# %%
dicc = {"USA" : [39.7837304,-100.445882], "AUSTRALIA" : [-24.7761086, 134.755], "SOUTH AFRICA" : 
    [-28.8166236, 24.991639], "NEW ZEALAND" : [-41.5000831, 172.8344077], "PAPUA NEW GUINEA" : [-5.6816069, 144.2489081]}

# %%
dicc ["USA"][0]
# Out:
# 39.7837304

# %%
paises = ["USA", "AUSTRALIA", "SOUTH AFRICA", "NEW ZEALAND","PAPUA NEW GUINEA"]

# %%
paises = []

for key, value in dicc.items():
        
    url = f'http://www.7timer.info/bin/api.pl?lon=-{value[1]}&lat={value[0]}&product=meteo&output=json'

    response = requests.get(url=url)
    response.status_code
    response.reason
    paises.append(response.json())

# %%
australia = pd.json_normalize(paises[1]["dataseries"])

# %%
pais = "australia"

# %%
australia ["country"] = pais

# %%
australia
# Out:
#     timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0           3           4      -9999     -9999     -9999
# 1           6           4      -9999     -9999     -9999
# 2           9           8      -9999     -9999     -9999
# 3          12           8      -9999     -9999     -9999
# 4          15           9      -9999     -9999     -9999
# ..        ...         ...        ...       ...       ...
# 59        180           2      -9999     -9999     -9999
# 60        183           4      -9999     -9999     -9999
# 61        186           3      -9999     -9999     -9999
# 62        189           7      -9999     -9999     -9999
# 63        192           5      -9999     -9999     -9999
#
#                                            rh_profile  \
# 0   [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1   [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 2   [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 3   [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 4   [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# ..                                                ...
# 59  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 60  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 61  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 62  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 63  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
#
#                                          wind_profile  temp2m  lifted_index  \
# 0   [{'layer': '950mb', 'direction': 230, 'speed':...      21            -1
# 1   [{'layer': '950mb', 'direction': 170, 'speed':...      21            -1
# 2   [{'layer': '950mb', 'direction': 200, 'speed':...      20            -1
# 3   [{'layer': '950mb', 'direction': 170, 'speed':...      20            -1
# 4   [{'layer': '950mb', 'direction': 175, 'speed':...      20            -1
# ..                                                ...     ...           ...
# 59  [{'layer': '950mb', 'direction': 100, 'speed':...      22             6
# 60  [{'layer': '950mb', 'direction': 85, 'speed': ...      22             6
# 61  [{'layer': '950mb', 'direction': 95, 'speed': ...      22             6
# 62  [{'layer': '950mb', 'direction': 85, 'speed': ...      22             6
# 63  [{'layer': '950mb', 'direction': 80, 'speed': ...      22             2
#
#     rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     12          1017      rain            2           0               190
# 1     12          1020      rain            3           0               160
# 2     12          1020      rain            3           0               180
# 3     11          1017      rain            3           0               165
# 4     10          1018      rain            3           0               195
# ..   ...           ...       ...          ...         ...               ...
# 59    11          1022      none            3           0               105
# 60    11          1023      none            3           0                95
# 61    11          1025      none            3           0               100
# 62    11          1023      none            3           0                90
# 63    10          1021      none            3           0                75
#
#     wind10m.speed    country
# 0               3  australia
# 1               3  australia
# 2               4  australia
# 3               3  australia
# 4               2  australia
# ..            ...        ...
# 59              3  australia
# 60              3  australia
# 61              3  australia
# 62              3  australia
# 63              3  australia
#
# [64 rows x 17 columns]

# %%
#FALTA METER EL CÓDIGO EN EL LOOP, HACER MERGE Y GUARDAR EN CSV
